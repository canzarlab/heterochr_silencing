# %%
import pandas as pd

# %%
import os

# %%
from functools import reduce

# %%
pd.options.mode.chained_assignment = None

# %% [markdown]
# ---------------------------

# %%
source_dir = '/data/parastou/RNAdeg/data/AllRNA/'
#source_dir = '/data/RNAdeg/fastq/RNA/'

# %%
#out_dir = '/data/parastou/RNAdeg/results/RipRna/'
out_dir = '/data/pablo/RNAdeg/results/RipRna/'

# %% [markdown]
# --------------

# %% [markdown]
# ## Workflow

# %% [markdown]
# - Unzip fastq files.
# - Truncate 0-length reads from fastq files.
# - Run STAR aligner.
# - Index .bam files.
# - Remove rRNA reads from .bam and add 'GE' tag to reads which map to genes (RemrRNA).
# - Calculate and save gene counts table for all given samples from .bam files.
# - TPM-normalize gene counts table and save.

# %% [markdown]
# ---------

# %%
def process_sample_names(names, col_name=None):
    
    ## select col_name
    if col_name is None:
        if isinstance(names, pd.DataFrame) and names.shape[0] == 1:
            col_name = names.columns[0]
        else:
            col_name = "sample_name"
    
    ## get dataframe
    if not isinstance(names, pd.DataFrame):

        ## create dataframe from list
        df = pd.DataFrame(data = names, columns=[col_name])
        
    else:
        
        ## already a dataframe
        df = names
        
    ## sort dataframe by col_name
    df = df.sort_values(by=[col_name]).reset_index(drop=True)
        
    ## get sample's prefix
    df["prefix"] = df[col_name].map(lambda x: x.split(".")[0])
    
    ## check for "duplicated" files (share same prefix) within the same directory.
    ## one should be careful and wonder why is that?
    n_samples = df.shape[0]
    df = df[~df.duplicated(subset="prefix", keep=False)] ## remove entries with duplicated prefix
    
    #assert(n_samples == df.shape[0])
    if n_samples != df.shape[0]:
        print("\n{}".format("-"*99))
        print(" Warning! Duplicated files (share same prefix) within the same directory. \n Will be ignored for now!")        
        print("{}\n".format("-"*99))

    #print("Number of files in `{}`: {}".format(col_name, df.shape[0]) )
    
    return df

# %% [markdown]
# ## 0 - Investigate Samples

# %% [markdown]
# ---------

# %% [markdown]
# ### Import Data

# %% [markdown]
# A. __Load `valid_samples.txt` file__

# %%
valid_samples = pd.read_csv(source_dir + 'valid_samples.txt', header=None, names = ["valid_sample"])
valid_samples = process_sample_names(valid_samples, col_name="valid_sample")
print("Number of valid samples (as given by Parastou): {}".format(valid_samples.shape[0]) )
# Out:
# Number of valid samples (as given by Parastou): 54

# %%
#valid_samples

# %% [markdown]
# B. __Load `remote_RNA_file_names.txt` file__

# %%
remote_samples = pd.read_csv(source_dir + 'remote_RNA_file_names.txt', header=None, names = ["remote_sample"])
remote_samples = process_sample_names(remote_samples, col_name="remote_sample")
remote_dir = "/data/cryohalic01/home/ag_halic/share/Conny/fastq_for_Stefan_RNAdeg"
print("Number of remote samples (as present in {}): {}".format(remote_dir, remote_samples.shape[0]))
# Out:
# Number of remote samples (as present in /data/cryohalic01/home/ag_halic/share/Conny/fastq_for_Stefan_RNAdeg): 32

# %%
#remote_samples

# %% [markdown]
# C. __Check in `source_dir` for sample files ('bz2', '.fastq', '.fastqsanger')__

# %%
file_formats = ('bz2', '.fastq', '.fastqsanger')
source_samples_names = [ff for ff in os.listdir(source_dir) if ff.endswith(file_formats)]
#source_samples_names = pd.read_csv(source_dir + 'sample_names.txt', header=None, names = ["source_sample"])
source_samples = process_sample_names(source_samples_names, col_name="source_sample")
print("Number of sample files in `source_dir` ({}): {}".format(source_dir, source_samples.shape[0]))
# Out:
# Number of sample files in `source_dir` (/data/parastou/RNAdeg/data/AllRNA/): 66

# %%
#source_samples

# %% [markdown]
# - This means there are __"duplicated" files__ (share same prefix) within the same directory. One should be careful and wonder __why is that__?

# %%
assert(len(source_samples_names) == source_samples.shape[0])

# %%
duplicated_files = sorted(list(set(source_samples_names).difference(source_samples.source_sample)))
duplicated_files
# Out:
# []

# %% [markdown]
# D. __Merge (Samples) DataFrames: [`source_dir`, `valid_samples.txt`, `remote_RNA_file_names.txt`]__

# %%
# compile the list of dataframes you want to merge
data_frames = [valid_samples, remote_samples, source_samples]

# %%
df_merged = reduce(lambda left, right: pd.merge(left,right,on=['prefix'], how='outer'), data_frames)

# %%
# sort
df_merged = df_merged.sort_values("prefix").reset_index(drop=True)
# shuffle columns
df_merged = df_merged[["prefix", "valid_sample", "remote_sample", "source_sample"]]
# set "prefix" as index
df_merged = df_merged.set_index("prefix")

# %%
df_merged.shape[0]
# Out:
# 67

# %%
#df_merged

# %% [markdown]
# ---------

# %% [markdown]
# ### __Compare  `source_dir` vs `valid_samples.txt`__

# %%
select_cols = ["valid_sample", "source_sample"]
source_vs_valid_samples = df_merged[select_cols]

# %% [markdown]
# This are samples that are either __not valid__ or __missing__

# %%
source_vs_valid_samples = source_vs_valid_samples[source_vs_valid_samples["valid_sample"].isna() != source_vs_valid_samples["source_sample"].isna()]
len(source_vs_valid_samples)
# Out:
# 14

# %% [markdown]
# - __Not valid__ samples (present in `source_dir` but not in `valid_samples.txt`)

# %%
not_valid_samples = source_vs_valid_samples[source_vs_valid_samples.valid_sample.isna()]
print("Number of NOT valid samples:", len(not_valid_samples))
# Out:
# Number of NOT valid samples: 13

# %%
#not_valid_samples

# %% [markdown]
# - __Missing__ samples (present in `valid_samples.txt` but not in `source_dir`): Ideally this should be 0

# %%
missing_samples = source_vs_valid_samples[source_vs_valid_samples.source_sample.isna()]
print("Number of missing samples (e.g. valid but are not in the `source_dir`:", len(missing_samples))
# Out:
# Number of missing samples (e.g. valid but are not in the `source_dir`: 1

# %% [markdown]
# - We see that some of the `valid_sample`s (7) seem to be missing an "A" at the end.
# - (1) `valid_sample` "302_S2RIP_2" is also missing but this the sample that we ignore because is raising an error.

# %%
missing_samples
# Out:
#             valid_sample source_sample
# prefix
# 302_S2RIP_2  302_S2RIP_2           NaN

# %% [markdown]
# ### __Compare  `source_dir` vs `remote_RNA_file_names.txt`__

# %%
select_cols = ["source_sample", "remote_sample"]
source_vs_remote_samples = df_merged[select_cols]

# %% [markdown]
# This are samples that are either present in __missing from source_dir__ or __missing from remote_dir__

# %%
source_vs_remote_samples = source_vs_remote_samples[source_vs_remote_samples["source_sample"].isna() != source_vs_remote_samples["remote_sample"].isna()]
len(source_vs_remote_samples)
# Out:
# 36

# %%
#source_vs_remote_samples

# %% [markdown]
# - __Missing from remote_dir__ samples (present in `source_dir` but not in `remote_RNA_file_names.txt`)

# %%
missing_from_remote = source_vs_remote_samples[source_vs_remote_samples.remote_sample.isna()]
print("Number of samples missing in the source_dir:", len(missing_from_remote))
# Out:
# Number of samples missing in the source_dir: 35

# %%
missing_from_remote.index.tolist()
# Out:
# ['1167_S5RIP_2',
#  '283_RNA_pA_4',
#  '301_RNA_pA_3',
#  '301_S2RIP_3',
#  '302_S2RIP_3',
#  '324S2RIP_1',
#  '324_RNA_pA_3',
#  '324_S2RIP_3',
#  '491S2RIP_1',
#  '491_S2RIP_3',
#  '504S2RIP_1',
#  '504S2RIP_2',
#  '504_RNA_pA_1',
#  '504_RNA_pA_2',
#  '530S2RIP_1',
#  '530S2RIP_2',
#  '530_RNA_pA_1',
#  '530_RNA_pA_2',
#  '591_S5RIP_1',
#  '63',
#  '638S2RIP_1',
#  '638S2RIP_2',
#  '638_RNA_pA_1',
#  '638_RNA_pA_2',
#  '63_RIPS5P',
#  '63_RNA_pA_3',
#  '63_RNA_pA_4',
#  '63_S2PRIP',
#  '63_S2Ph_RIP',
#  '63_S2RIP_2',
#  '63_S5Ph_RIP',
#  '65',
#  '80S2RIP_1',
#  '80S2RIP_2',
#  '80pARNA_2']

# %% [markdown]
# - __Missing from source_dir__ samples (present in `remote_RNA_file_names.txt` but not in `source_dir`)

# %%
missing_from_source = source_vs_remote_samples[source_vs_remote_samples.source_sample.isna()]
print("Number of missing samples (e.g. valid but are not in the `source_dir`:", len(missing_from_source))
# Out:
# Number of missing samples (e.g. valid but are not in the `source_dir`: 1

# %% [markdown]
# - (1) `remote_sample` "302_S2RIP_2" is missing but this the sample that we ignore because is raising an error.

# %%
missing_from_source
# Out:
#             source_sample          remote_sample
# prefix
# 302_S2RIP_2           NaN  302_S2RIP_2.fastq.bz2

# %% [markdown]
# ---------

# %% [markdown]
# ### Samples used in Analysis

# %% [markdown]
# __Errors__:
# -  302_S2RIP_2.fastq
# -  63_RNA_pA_3.fastq

# %% [markdown]
# __Ignore samples that are not valid, also ignore samples that give errors__

# %%
#ignore_files = set(["302_S2RIP_2", "63_RNA_pA_3"])
ignore_files = set(["302_S2RIP_2"]) ## we already removed the file from directory
## union
ignore_files = set(not_valid_samples.index | ignore_files)

# %%
ignore_files = sorted([ff + "."  for ff in ignore_files])
print("Number of samples that will be ignored:", len(ignore_files))
# Out:
# Number of samples that will be ignored: 22

# %%
#ignore_files

# %% [markdown]
# __Samples used in Analysis are present in `source_dir` and `valid_samples.txt`__

# %%
prefix_files = df_merged[(~df_merged.source_sample.isna()) & (~df_merged.valid_sample.isna())].index.tolist()
print("Total number of samples that will be analyzed:", len(prefix_files))
# Out:
# Total number of samples that will be analyzed: 46

# %%
#prefix_files

# %% [markdown]
# ---------

# %% [markdown]
# ### 1 - Prepare output folders

# %%
out_bam = os.path.join(out_dir, 'bams')
out_tagged = os.path.join(out_dir, 'tagged_bams')
xp_data = os.path.join(out_dir, 'xp_data')

# %%
if not os.path.isdir(out_bam):    
    #!mkdir $out_bam
    # !mkdir -p $out_bam

# %%
if not os.path.isdir(out_tagged):    
    #!mkdir $out_tagged
    # !mkdir -p $out_tagged

# %%
if not os.path.isdir(xp_data):    
    #!mkdir $xp_data
    # !mkdir -p $xp_data

# %% [markdown]
# -----------------------

# %% [markdown]
# ### 2 - Unzip fastq files.

# %%
for filename in os.listdir(source_dir):
    if filename.endswith('bz2'):
        cat('Decompressing file ...\n', filename)
        filepath = os.path.join(source_dir, filename)
        # !bzip2 -d $filepath

# %% [markdown]
# ### Optional step: remove truncated reads from fastq files.

# %%
# for filename in os.listdir(source_dir):
#     if filename.endswith('.fastq'):
        
#         filepath = os.path.join(source_dir, filename)
#         outfilepath = os.path.join(source_dir, filename.split('.fastq')[0] + '.ztr.fastq')
#         !echo $outfilepath
#         !bioawk -cfastx 'length($seq) > 0 {print "@"$name"\n"$seq"\n+\n"$qual} $filepath  >> $outfilepath'
#         #!rm $filepath

# %% [markdown]
# ### 3 - Align fastq files

# %%
# Set STAR runtime parameters.
def star_command(in_file):
    
    star = '/home/parastou/star_2.5.1b'
    n_threads = 20
    genome_dir = '/data/parastou/RNAdeg/genomes/spombe/staridx/'
    
    command = star + ' --runThreadN ' + str(n_threads) + ' --genomeDir ' + genome_dir + ' --readFilesIn ' \
    + source_dir + in_file + ' --outFileNamePrefix ' + os.path.join(out_bam , in_file.split('fastq')[0]) \
    + ' --outSAMtype BAM SortedByCoordinate'
    
    return command

# %% [markdown]
# __Errors__:
# -  302_S2RIP_2.fastq:
#     - EXITING because of fatal ERROR: not enough memory for BAM sorting:
#         - SOLUTION: re-run STAR with at least --limitBAMsortRAM 2821915860
# -  63_RNA_pA_3.fastq
#     - EXITING because of FATAL ERROR in reads input: short read sequence line: 1
#         - Read Name=@L183:414:CCGY1ANXX:4:1311:17580:12058:1:N:0:0:CACGATAT
#         - Read Sequence====
#         - DEF_readNameLengthMax=50000
#         - DEF_readSeqLengthMax=500

# %%
# Run STAR
for filename in os.listdir(source_dir):
    
    #if filename.endswith(('.fastq', '.fastqsanger')):
    if filename.endswith(('.fastq', '.fastqsanger')) and not filename.startswith(ignore_files):
   
        print(filename)
        command = star_command(filename)
        print(command)
        # !$command
# Out:
# 1167_pA_2.fastq
# /home/parastou/star_2.5.1b --runThreadN 20 --genomeDir /data/parastou/RNAdeg/genomes/spombe/staridx/ --readFilesIn /data/parastou/RNAdeg/data/AllRNA/1167_pA_2.fastq --outFileNamePrefix /data/pablo/RNAdeg/results/RipRna/bams/1167_pA_2. --outSAMtype BAM SortedByCoordinate
# Nov 20 11:31:14 ..... Started STAR run
# Nov 20 11:31:14 ..... Loading genome
# Nov 20 11:31:25 ..... Started mapping
# Nov 20 11:32:27 ..... Started sorting BAM
# Nov 20 11:32:41 ..... Finished successfully
# 63.fastq
# /home/parastou/star_2.5.1b --runThreadN 20 --genomeDir /data/parastou/RNAdeg/genomes/spombe/staridx/ --readFilesIn /data/parastou/RNAdeg/data/AllRNA/63.fastq --outFileNamePrefix /data/pablo/RNAdeg/results/RipRna/bams/63. --outSAMtype BAM SortedByCoordinate
# Nov 20 11:32:42 ..... Started STAR run
# Nov 20 11:32:42 ..... Loading genome
# Nov 20 11:32:43 ..... Started mapping
# Nov 20 11:33:33 ..... Started sorting BAM
# Nov 20 11:33:49 ..... Finished successfully
# 65.fastq
# /home/parastou/star_2.5.1b --runThreadN 20 --genomeDir /data/parastou/RNAdeg/genomes/spombe/staridx/ --readFilesIn /data/parastou/RNAdeg/data/AllRNA/65.fastq --outFileNamePrefix /data/pablo/RNAdeg/results/RipRna/bams/65. --outSAMtype BAM SortedByCoordinate
# Nov 20 11:33:50 ..... Started STAR run
# Nov 20 11:33:50 ..... Loading genome
# Nov 20 11:33:51 ..... Started mapping
# Nov 20 11:38:13 ..... Started sorting BAM
# Nov 20 11:38:26 ..... Finished successfully
# 63_RIPS5P.fastq
# /home/parastou/star_2.5.1b --runThreadN 20 --genomeDir /data/parastou/RNAdeg/genomes/spombe/staridx/ --readFilesIn /data/parastou/RNAdeg/data/AllRNA/63_RIPS5P.fastq --outFileNamePrefix /data/pablo/RNAdeg/results/RipRna/bams/63_RIPS5P. --outSAMtype BAM SortedByCoordinate
# Nov 20 11:38:27 ..... Started STAR run
# Nov 20 11:38:27 ..... Loading genome
# Nov 20 11:38:27 ..... Started mapping
# Nov 20 11:42:21 ..... Started sorting BAM
# Nov 20 11:46:37 ..... Finished successfully
# 63_S2Ph_RIP.fastq
# /home/parastou/star_2.5.1b --runThreadN 20 --genomeDir /data/parastou/RNAdeg/genomes/spombe/staridx/ --readFilesIn /data/parastou/RNAdeg/data/AllRNA/63_S2Ph_RIP.fastq --outFileNamePrefix /data/pablo/RNAdeg/results/RipRna/bams/63_S2Ph_RIP. --outSAMtype BAM SortedByCoordinate
# Nov 20 11
pA.fastq
# /home/parastou/star_2.5.1b --runThreadN 20 --genomeDir /data/parastou/RNAdeg/genomes/spombe/staridx/ --readFilesIn /data/parastou/RNAdeg/data/AllRNA/80_RNA_pA.fastq --outFileNamePrefix /data/pablo/RNAdeg/results/RipRna/bams/80_RNA_pA. --outSAMtype BAM SortedByCoordinate
# Nov 20 14:14:43 ..... Started STAR run
# Nov 20 14:14:43 ..... Loading genome
# Nov 20 14:14:44 ..... Started mapping
# Nov 20 14:14:52 ..... Started sorting BAM
# Nov 20 14:14:56 ..... Finished successfully
# 301_RNA_pA.fastq
# /home/parastou/star_2.5.1b --runThreadN 20 --genomeDir /data/parastou/RNAdeg/genomes/spombe/staridx/ --readFilesIn /data/parastou/RNAdeg/data/AllRNA/301_RNA_pA.fastq --outFileNamePrefix /data/pablo/RNAdeg/results/RipRna/bams/301_RNA_pA. --outSAMtype BAM SortedByCoordinate
# Nov 20 14:14:56 ..... Started STAR run
# Nov 20 14:14:56 ..... Loading genome
# Nov 20 14:14:57 ..... Started mapping
# Nov 20 14:15:11 ..... Started sorting BAM
# Nov 20 14:15:17 ..... Finished successfully
# 302_RNA_pA.fastq
# /home/parastou/star_2.5.1b --runThreadN 20 --genomeDir /data/parastou/RNAdeg/genomes/spombe/staridx/ --readFilesIn /data/parastou/RNAdeg/data/AllRNA/302_RNA_pA.fastq --outFileNamePrefix /data/pablo/RNAdeg/results/RipRna/bams/302_RNA_pA. --outSAMtype BAM SortedByCoordinate
# Nov 20 14:15:17 ..... Started STAR run
# Nov 20 14:15:17 ..... Loading genome
# Nov 20 14:15:18 ..... Started mapping
# Nov 20 14:15:50 ..... Started sorting BAM
# Nov 20 14:16:09 ..... Finished successfully
# 324_RNA_pA.fastq
# /home/parastou/star_2.5.1b --runThreadN 20 --genomeDir /data/parastou/RNAdeg/genomes/spombe/staridx/ --readFilesIn /data/parastou/RNAdeg/data/AllRNA/324_RNA_pA.fastq --outFileNamePrefix /data/pablo/RNAdeg/results/RipRna/bams/324_RNA_pA. --outSAMtype BAM SortedByCoordinate
# Nov 20 14:16:11 ..... Started STAR run
# Nov 20 14:16:11 ..... Loading genome
# Nov 20 14:16:11 ..... Started mapping
# Nov 20 14:16:25 ..... Started sorting BAM
# Nov 20 14:16:30 ..... Finished successfully
# 491_RNA_pA.fastq
# /home/parastou/star_2.5.1b --runThreadN 20 --genomeDir /data/parastou/RNAdeg/genomes/spombe/staridx/ --readFilesIn /data/parastou/RNAdeg/data/AllRNA/491_RNA_pA.fastq --outFileNamePrefix /data/pablo/RNAdeg/results/RipRna/bams/491_RNA_pA. --outSAMtype BAM SortedByCoordinate
# Nov 20 14:16:30 ..... Started STAR run
# Nov 20 14:16:30 ..... Loading genome
# Nov 20 14:16:31 ..... Started mapping
# Nov 20 14:17:25 ..... Started sorting BAM
# Nov 20 14:17:41 ..... Finished successfully
# 510_RNA_pA.fastq
# /home/parastou/star_2.5.1b --runThreadN 20 --genomeDir /data/parastou/RNAdeg/genomes/spombe/staridx/ --readFilesIn /data/parastou/RNAdeg/data/AllRNA/510_RNA_pA.fastq --outFileNamePrefix /data/pablo/RNAdeg/results/RipRna/bams/510_RNA_pA. --outSAMtype BAM SortedByCoordinate
# Nov 20 14:17:41 ..... Started STAR run
# Nov 20 14:17:41 ..... Loading genome
# Nov 20 14:17:42 ..... Started mapping
# Nov 20 14:18:28 ..... Started sorting BAM
# Nov 20 14:18:44 ..... Finished successfully

# %% [markdown]
# __Errors__:
# -  302_S2RIP_2.fastq:
#     - samtools index: "/data/pablo/RNAdeg/results/RipRna/bams/302_S2RIP_2.Aligned.sortedByCoord.out.bam" is in a format that cannot be usefully indexed
#
# -  63_RNA_pA_3.fastq
#     - samtools index: "/data/pablo/RNAdeg/results/RipRna/bams/63_RNA_pA_3.Aligned.sortedByCoord.out.bam" is in a format that cannot be usefully indexed

# %%
# Index alignment files.
for filename in os.listdir(out_bam):
 
    #if filename.endswith('.Aligned.sortedByCoord.out.bam'):
    if filename.endswith('.Aligned.sortedByCoord.out.bam') and not filename.startswith(ignore_files):

        filepath = os.path.join(out_bam, filename)
        # !samtools index $filepath
# Out:
# samtools index: "/data/pablo/RNAdeg/results/RipRna/bams/302_S2RIP_2.Aligned.sortedByCoord.out.bam" is in a format that cannot be usefully indexed
# samtools index: "/data/pablo/RNAdeg/results/RipRna/bams/63_RNA_pA_3.Aligned.sortedByCoord.out.bam" is in a format that cannot be usefully indexed

# %% [markdown]
# ### 4 - Tag bam files with gene IDs

# %%
# Set RemrRNA command runtime parameters.
def remrrna_command():
    
    remrrna = '/data/parastou/RNAdeg/pyRNAdeg/RemrRNA.py'
    annotation = '/data/parastou/RNAdeg/annotation/schizosaccharomyces_pombe.chr.extended.csv'
    
    command = remrrna + ' -d ' + out_bam + ' -g ' + annotation + ' -o ' + out_tagged
    
    return command

# %%
# Run RemrRNA
remrrna = remrrna_command()
# !$remrrna
# Out:
# INFO:__main__:Call to RemrRNA module.
# Call to RemrRNA module.
# INFO:__main__:
#
# INFO:__main__:This module removes ribosomal-RNA related reads from given .bam files
# This module removes ribosomal-RNA related reads from given .bam files
# INFO:__main__:It produces a gene-tagged .bam file as output.
# It produces a gene-tagged .bam file as output.
# INFO:__main__:----------------------------------------
# ----------------------------------------
# INFO:__main__:Filtering ribosomal-RNA reads and tagging started.
# Filtering ribosomal-RNA reads and tagging started.
# INFO:__main__:Source directory:	/data/pablo/RNAdeg/results/RipRna/bams
# Source directory:	/data/pablo/RNAdeg/results/RipRna/bams
# INFO:__main__:--------------------------------------------------
# --------------------------------------------------
# INFO:__main__:Sample name:	1167_pA_2.Aligned.sortedByCoord.out.bam
# Sample name:	1167_pA_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			19,153,961
# Total reads:			19,153,961
# INFO:__main__:Spliced reads ignored:		601,077
# Spliced reads ignored:		601,077
# INFO:__main__:Total reads mapped to genes:	17,602,604
# Total reads mapped to genes:	17,602,604
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_pA_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	63.Aligned.sortedByCoord.out.bam
# Sample name:	63.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			19,410,169
# Total reads:			19,410,169
# INFO:__main__:Spliced reads ignored:		546,362
# Spliced reads ignored:		546,362
# INFO:__main__:Total reads mapped to genes:	17,854,944
# Total reads mapped to genes:	17,854,944
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	65.Aligned.sortedByCoord.out.bam
# Sample name:	65.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			18,009,267
# Total reads:			18,009,267
# INFO:__main__:Spliced reads ignored:		497,230
# Spliced reads ignored:		497,230
# INFO:__main__:Total reads mapped to genes:	16,606,288
# Total reads mapped to genes:	16,606,288
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/65.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/65.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	63_RIPS5P.Aligned.sortedByCoord.out.bam
# Sample name:	63_RIPS5P.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			33,202,799
# Total reads:			33,202,799
# INFO:__main__:Spliced reads ignored:		88,951
# Spliced reads ignored:		88,951
# INFO:__main__:Total reads mapped to genes:	7,883,013
# Total reads mapped to genes:	7,883,013
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63_RIPS5P.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63_RIPS5P.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	63_S2Ph_RIP.Aligned.sortedByCoord.out.bam
# Sample name:	63_S2Ph_RIP.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			16,991,670
# Total reads:			16,991,670
# INFO:__main__:Spliced reads ignored:		37,112
# Spliced reads ignored:		37,112
# INFO:__main__:Total reads mapped to genes:	5,657,208
# Total reads mapped to genes:	5,657,208
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63_S2Ph_RIP.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63_S2Ph_RIP.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	63_S2PRIP.Aligned.sortedByCoord.out.bam
# Sample name:	63_S2PRIP.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			25,942,299
# Total reads:			25,942,299
# INFO:__main__:Spliced reads ignored:		85,336
# Spliced reads ignored:		85,336
# INFO:__main__:Total reads mapped to genes:	6,449,064
# Total reads mapped to genes:	6,449,064
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63_S2PRIP.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63_S2PRIP.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	63_S2RIP_2.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	63_S2RIP_2.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			15,733,435
# Total reads:			15,733,435
# INFO:__main__:Spliced reads ignored:		39,900
# Spliced reads ignored:		39,900
# INFO:__main__:Total reads mapped to genes:	1,553,320
# Total reads mapped to genes:	1,553,320
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63_S2RIP_2.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63_S2RIP_2.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	63_S5Ph_RIP.Aligned.sortedByCoord.out.bam
# Sample name:	63_S5Ph_RIP.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			6,010,821
# Total reads:			6,010,821
# INFO:__main__:Spliced reads ignored:		12,215
# Spliced reads ignored:		12,215
# INFO:__main__:Total reads mapped to genes:	1,510,384
# Total reads mapped to genes:	1,510,384
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63_S5Ph_RIP.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63_S5Ph_RIP.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	80_S2RIP.Aligned.sortedByCoord.out.bam
# Sample name:	80_S2RIP.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			18,074,957
# Total reads:			18,074,957
# INFO:__main__:Spliced reads ignored:		45,905
# Spliced reads ignored:		45,905
# INFO:__main__:Total reads mapped to genes:	4,234,231
# Total reads mapped to genes:	4,234,231
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/80_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/80_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	80S2RIP_1.Aligned.sortedByCoord.out.bam
# Sample name:	80S2RIP_1.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			13,575,895
# Total reads:			13,575,895
# INFO:__main__:Spliced reads ignored:		37,328
# Spliced reads ignored:		37,328
# INFO:__main__:Total reads mapped to genes:	1,649,853
# Total reads mapped to genes:	1,649,853
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/80S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/80S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	80S2RIP_2.Aligned.sortedByCoord.out.bam
# Sample name:	80S2RIP_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			16,194,814
# Total reads:			16,194,814
# INFO:__main__:Spliced reads ignored:		44,572
# Spliced reads ignored:		44,572
# INFO:__main__:Total reads mapped to genes:	1,722,219
# Total reads mapped to genes:	1,722,219
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/80S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/80S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	301_S2RIP_2.Aligned.sortedByCoord.out.bam
# Sample name:	301_S2RIP_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			17,154,070
# Total reads:			17,154,070
# INFO:__main__:Spliced reads ignored:		39,546
# Spliced reads ignored:		39,546
# INFO:__main__:Total reads mapped to genes:	2,671,327
# Total reads mapped to genes:	2,671,327
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/301_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/301_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	301_S2RIP_3.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	301_S2RIP_3.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			16,940,467
# Total reads:			16,940,467
# INFO:__main__:Spliced reads ignored:		47,297
# Spliced reads ignored:		47,297
# INFO:__main__:Total reads mapped to genes:	1,897,600
# Total reads mapped to genes:	1,897,600
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/301_S2RIP_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/301_S2RIP_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	301_S2RIP.Aligned.sortedByCoord.out.bam
# Sample name:	301_S2RIP.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			18,159,048
# Total reads:			18,159,048
# INFO:__main__:Spliced reads ignored:		48,150
# Spliced reads ignored:		48,150
# INFO:__main__:Total reads mapped to genes:	5,086,028
# Total reads mapped to genes:	5,086,028
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/301_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/301_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	302_S2RIP_3.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	302_S2RIP_3.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			16,579,898
# Total reads:			16,579,898
# INFO:__main__:Spliced reads ignored:		52,027
# Spliced reads ignored:		52,027
# INFO:__main__:Total reads mapped to genes:	2,712,915
# Total reads mapped to genes:	2,712,915
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/302_S2RIP_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/302_S2RIP_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	302_S2RIP.Aligned.sortedByCoord.out.bam
# Sample name:	302_S2RIP.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			15,751,893
# Total reads:			15,751,893
# INFO:__main__:Spliced reads ignored:		38,557
# Spliced reads ignored:		38,557
# INFO:__main__:Total reads mapped to genes:	3,809,496
# Total reads mapped to genes:	3,809,496
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/302_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/302_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	324_S2RIP_2.Aligned.sortedByCoord.out.bam
# Sample name:	324_S2RIP_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			2,464,458
# Total reads:			2,464,458
# INFO:__main__:Spliced reads ignored:		8,622
# Spliced reads ignored:		8,622
# INFO:__main__:Total reads mapped to genes:	415,637
# Total reads mapped to genes:	415,637
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	324_S2RIP_3.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	324_S2RIP_3.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			15,090,396
# Total reads:			15,090,396
# INFO:__main__:Spliced reads ignored:		47,499
# Spliced reads ignored:		47,499
# INFO:__main__:Total reads mapped to genes:	2,414,397
# Total reads mapped to genes:	2,414,397
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324_S2RIP_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324_S2RIP_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	324_S2RIP.Aligned.sortedByCoord.out.bam
# Sample name:	324_S2RIP.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			17,284,517
# Total reads:			17,284,517
# INFO:__main__:Spliced reads ignored:		51,130
# Spliced reads ignored:		51,130
# INFO:__main__:Total reads mapped to genes:	4,814,713
# Total reads mapped to genes:	4,814,713
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	324S2RIP_1.Aligned.sortedByCoord.out.bam
# Sample name:	324S2RIP_1.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			8,831,510
# Total reads:			8,831,510
# INFO:__main__:Spliced reads ignored:		112,113
# Spliced reads ignored:		112,113
# INFO:__main__:Total reads mapped to genes:	225,047
# Total reads mapped to genes:	225,047
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	491_S2RIP_2.Aligned.sortedByCoord.out.bam
# Sample name:	491_S2RIP_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			15,389,415
# Total reads:			15,389,415
# INFO:__main__:Spliced reads ignored:		50,826
# Spliced reads ignored:		50,826
# INFO:__main__:Total reads mapped to genes:	2,497,264
# Total reads mapped to genes:	2,497,264
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/491_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/491_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	491_S2RIP_3.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	491_S2RIP_3.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			14,894,953
# Total reads:			14,894,953
# INFO:__main__:Spliced reads ignored:		42,748
# Spliced reads ignored:		42,748
# INFO:__main__:Total reads mapped to genes:	2,548,592
# Total reads mapped to genes:	2,548,592
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/491_S2RIP_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/491_S2RIP_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	491_S2RIP.Aligned.sortedByCoord.out.bam
# Sample name:	491_S2RIP.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			24,641,944
# Total reads:			24,641,944
# INFO:__main__:Spliced reads ignored:		64,007
# Spliced reads ignored:		64,007
# INFO:__main__:Total reads mapped to genes:	5,306,415
# Total reads mapped to genes:	5,306,415
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/491_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/491_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	491S2RIP_1.Aligned.sortedByCoord.out.bam
# Sample name:	491S2RIP_1.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			7,750,987
# Total reads:			7,750,987
# INFO:__main__:Spliced reads ignored:		103,640
# Spliced reads ignored:		103,640
# INFO:__main__:Total reads mapped to genes:	104,542
# Total reads mapped to genes:	104,542
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/491S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/491S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	504S2RIP_1.Aligned.sortedByCoord.out.bam
# Sample name:	504S2RIP_1.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			14,889,605
# Total reads:			14,889,605
# INFO:__main__:Spliced reads ignored:		51,407
# Spliced reads ignored:		51,407
# INFO:__main__:Total reads mapped to genes:	2,210,429
# Total reads mapped to genes:	2,210,429
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/504S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/504S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	504S2RIP_2.Aligned.sortedByCoord.out.bam
# Sample name:	504S2RIP_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			14,594,016
# Total reads:			14,594,016
# INFO:__main__:Spliced reads ignored:		56,209
# Spliced reads ignored:		56,209
# INFO:__main__:Total reads mapped to genes:	2,039,220
# Total reads mapped to genes:	2,039,220
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/504S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/504S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	510_S2RIP.Aligned.sortedByCoord.out.bam
# Sample name:	510_S2RIP.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			20,638,391
# Total reads:			20,638,391
# INFO:__main__:Spliced reads ignored:		55,616
# Spliced reads ignored:		55,616
# INFO:__main__:Total reads mapped to genes:	4,123,161
# Total reads mapped to genes:	4,123,161
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/510_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/510_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	530S2RIP_1.Aligned.sortedByCoord.out.bam
# Sample name:	530S2RIP_1.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			11,564,816
# Total reads:			11,564,816
# INFO:__main__:Spliced reads ignored:		36,704
# Spliced reads ignored:		36,704
# INFO:__main__:Total reads mapped to genes:	1,303,290
# Total reads mapped to genes:	1,303,290
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/530S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/530S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	530S2RIP_2.Aligned.sortedByCoord.out.bam
# Sample name:	530S2RIP_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			14,268,624
# Total reads:			14,268,624
# INFO:__main__:Spliced reads ignored:		44,915
# Spliced reads ignored:		44,915
# INFO:__main__:Total reads mapped to genes:	1,775,904
# Total reads mapped to genes:	1,775,904
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/530S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/530S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	591_S2RIP_2.Aligned.sortedByCoord.out.bam
# Sample name:	591_S2RIP_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			18,492,744
# Total reads:			18,492,744
# INFO:__main__:Spliced reads ignored:		61,284
# Spliced reads ignored:		61,284
# INFO:__main__:Total reads mapped to genes:	2,958,945
# Total reads mapped to genes:	2,958,945
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/591_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/591_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	591_S5RIP_1.Aligned.sortedByCoord.out.bam
# Sample name:	591_S5RIP_1.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			16,185,052
# Total reads:			16,185,052
# INFO:__main__:Spliced reads ignored:		49,649
# Spliced reads ignored:		49,649
# INFO:__main__:Total reads mapped to genes:	3,946,873
# Total reads mapped to genes:	3,946,873
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/591_S5RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/591_S5RIP_1.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	638S2RIP_1.Aligned.sortedByCoord.out.bam
# Sample name:	638S2RIP_1.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			13,450,747
# Total reads:			13,450,747
# INFO:__main__:Spliced reads ignored:		33,753
# Spliced reads ignored:		33,753
# INFO:__main__:Total reads mapped to genes:	1,490,933
# Total reads mapped to genes:	1,490,933
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/638S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/638S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	638S2RIP_2.Aligned.sortedByCoord.out.bam
# Sample name:	638S2RIP_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			12,221,421
# Total reads:			12,221,421
# INFO:__main__:Spliced reads ignored:		33,758
# Spliced reads ignored:		33,758
# INFO:__main__:Total reads mapped to genes:	1,422,894
# Total reads mapped to genes:	1,422,894
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/638S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/638S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	1113_S2RIP.Aligned.sortedByCoord.out.bam
# Sample name:	1113_S2RIP.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			12,273,254
# Total reads:			12,273,254
# INFO:__main__:Spliced reads ignored:		35,823
# Spliced reads ignored:		35,823
# INFO:__main__:Total reads mapped to genes:	4,374,829
# Total reads mapped to genes:	4,374,829
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1113_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1113_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	1167_S2RIP_2.Aligned.sortedByCoord.out.bam
# Sample name:	1167_S2RIP_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			22,464,998
# Total reads:			22,464,998
# INFO:__main__:Spliced reads ignored:		57,795
# Spliced reads ignored:		57,795
# INFO:__main__:Total reads mapped to genes:	2,317,690
# Total reads mapped to genes:	2,317,690
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	1167_S2RIP.Aligned.sortedByCoord.out.bam
# Sample name:	1167_S2RIP.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			14,333,644
# Total reads:			14,333,644
# INFO:__main__:Spliced reads ignored:		30,959
# Spliced reads ignored:		30,959
# INFO:__main__:Total reads mapped to genes:	2,104,877
# Total reads mapped to genes:	2,104,877
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	1167_S5RIP_2.Aligned.sortedByCoord.out.bam
# Sample name:	1167_S5RIP_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			21,117,349
# Total reads:			21,117,349
# INFO:__main__:Spliced reads ignored:		29,158
# Spliced reads ignored:		29,158
# INFO:__main__:Total reads mapped to genes:	1,243,561
# Total reads mapped to genes:	1,243,561
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_S5RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_S5RIP_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	1168_S2RIP_2.Aligned.sortedByCoord.out.bam
# Sample name:	1168_S2RIP_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			23,188,416
# Total reads:			23,188,416
# INFO:__main__:Spliced reads ignored:		39,898
# Spliced reads ignored:		39,898
# INFO:__main__:Total reads mapped to genes:	2,047,461
# Total reads mapped to genes:	2,047,461
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1168_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1168_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	1168_S2RIP.Aligned.sortedByCoord.out.bam
# Sample name:	1168_S2RIP.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			16,081,973
# Total reads:			16,081,973
# INFO:__main__:Spliced reads ignored:		36,378
# Spliced reads ignored:		36,378
# INFO:__main__:Total reads mapped to genes:	1,197,698
# Total reads mapped to genes:	1,197,698
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1168_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1168_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	324_RNA_pA_3.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	324_RNA_pA_3.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			13,349,405
# Total reads:			13,349,405
# INFO:__main__:Spliced reads ignored:		552,509
# Spliced reads ignored:		552,509
# INFO:__main__:Total reads mapped to genes:	12,345,759
# Total reads mapped to genes:	12,345,759
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324_RNA_pA_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324_RNA_pA_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	1168_pA_2.Aligned.sortedByCoord.out.bam
# Sample name:	1168_pA_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			16,075,322
# Total reads:			16,075,322
# INFO:__main__:Spliced reads ignored:		465,790
# Spliced reads ignored:		465,790
# INFO:__main__:Total reads mapped to genes:	14,639,351
# Total reads mapped to genes:	14,639,351
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1168_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1168_pA_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	1113_pA.Aligned.sortedByCoord.out.bam
# Sample name:	1113_pA.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			26,461,506
# Total reads:			26,461,506
# INFO:__main__:Spliced reads ignored:		814,160
# Spliced reads ignored:		814,160
# INFO:__main__:Total reads mapped to genes:	24,230,150
# Total reads mapped to genes:	24,230,150
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1113_pA.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1113_pA.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	1167_pA.Aligned.sortedByCoord.out.bam
# Sample name:	1167_pA.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			27,868,007
# Total reads:			27,868,007
# INFO:__main__:Spliced reads ignored:		870,482
# Spliced reads ignored:		870,482
# INFO:__main__:Total reads mapped to genes:	25,490,955
# Total reads mapped to genes:	25,490,955
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_pA.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_pA.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	1168_pA.Aligned.sortedByCoord.out.bam
# Sample name:	1168_pA.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			3,078,252
# Total reads:			3,078,252
# INFO:__main__:Spliced reads ignored:		93,609
# Spliced reads ignored:		93,609
# INFO:__main__:Total reads mapped to genes:	2,807,656
# Total reads mapped to genes:	2,807,656
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1168_pA.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/1168_pA.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	510_RNA_pA_2.Aligned.sortedByCoord.out.bam
# Sample name:	510_RNA_pA_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			21,225,540
# Total reads:			21,225,540
# INFO:__main__:Spliced reads ignored:		570,146
# Spliced reads ignored:		570,146
# INFO:__main__:Total reads mapped to genes:	19,635,671
# Total reads mapped to genes:	19,635,671
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/510_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/510_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	301_RNA_pA_2.Aligned.sortedByCoord.out.bam
# Sample name:	301_RNA_pA_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			16,689,040
# Total reads:			16,689,040
# INFO:__main__:Spliced reads ignored:		662,797
# Spliced reads ignored:		662,797
# INFO:__main__:Total reads mapped to genes:	15,056,234
# Total reads mapped to genes:	15,056,234
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/301_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/301_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	302_RNA_pA_2.Aligned.sortedByCoord.out.bam
# Sample name:	302_RNA_pA_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			14,098,264
# Total reads:			14,098,264
# INFO:__main__:Spliced reads ignored:		498,473
# Spliced reads ignored:		498,473
# INFO:__main__:Total reads mapped to genes:	12,986,168
# Total reads mapped to genes:	12,986,168
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/302_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/302_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	324_RNA_pA_2.Aligned.sortedByCoord.out.bam
# Sample name:	324_RNA_pA_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			16,890,011
# Total reads:			16,890,011
# INFO:__main__:Spliced reads ignored:		612,845
# Spliced reads ignored:		612,845
# INFO:__main__:Total reads mapped to genes:	15,041,412
# Total reads mapped to genes:	15,041,412
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	491_RNA_pA_2.Aligned.sortedByCoord.out.bam
# Sample name:	491_RNA_pA_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			22,536,290
# Total reads:			22,536,290
# INFO:__main__:Spliced reads ignored:		852,497
# Spliced reads ignored:		852,497
# INFO:__main__:Total reads mapped to genes:	20,804,301
# Total reads mapped to genes:	20,804,301
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/491_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/491_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	80pARNA_2.Aligned.sortedByCoord.out.bam
# Sample name:	80pARNA_2.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			13,323,511
# Total reads:			13,323,511
# INFO:__main__:Spliced reads ignored:		470,799
# Spliced reads ignored:		470,799
# INFO:__main__:Total reads mapped to genes:	12,423,716
# Total reads mapped to genes:	12,423,716
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/80pARNA_2.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/80pARNA_2.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	63_RNA_pA_4.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	63_RNA_pA_4.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			14,219,928
# Total reads:			14,219,928
# INFO:__main__:Spliced reads ignored:		569,997
# Spliced reads ignored:		569,997
# INFO:__main__:Total reads mapped to genes:	13,141,023
# Total reads mapped to genes:	13,141,023
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63_RNA_pA_4.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/63_RNA_pA_4.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	283_RNA_pA_4.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	283_RNA_pA_4.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			15,268,985
# Total reads:			15,268,985
# INFO:__main__:Spliced reads ignored:		581,955
# Spliced reads ignored:		581,955
# INFO:__main__:Total reads mapped to genes:	13,909,010
# Total reads mapped to genes:	13,909,010
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/283_RNA_pA_4.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/283_RNA_pA_4.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	301_RNA_pA_3.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	301_RNA_pA_3.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			13,287,929
# Total reads:			13,287,929
# INFO:__main__:Spliced reads ignored:		517,675
# Spliced reads ignored:		517,675
# INFO:__main__:Total reads mapped to genes:	12,285,308
# Total reads mapped to genes:	12,285,308
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/301_RNA_pA_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/301_RNA_pA_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	504_RNA_pA_1.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	504_RNA_pA_1.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			16,540,223
# Total reads:			16,540,223
# INFO:__main__:Spliced reads ignored:		534,753
# Spliced reads ignored:		534,753
# INFO:__main__:Total reads mapped to genes:	14,742,015
# Total reads mapped to genes:	14,742,015
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/504_RNA_pA_1.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/504_RNA_pA_1.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	504_RNA_pA_2.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	504_RNA_pA_2.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			13,542,881
# Total reads:			13,542,881
# INFO:__main__:Spliced reads ignored:		431,814
# Spliced reads ignored:		431,814
# INFO:__main__:Total reads mapped to genes:	12,213,377
# Total reads mapped to genes:	12,213,377
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/504_RNA_pA_2.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/504_RNA_pA_2.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	530_RNA_pA_1.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	530_RNA_pA_1.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			16,959,495
# Total reads:			16,959,495
# INFO:__main__:Spliced reads ignored:		612,733
# Spliced reads ignored:		612,733
# INFO:__main__:Total reads mapped to genes:	15,331,342
# Total reads mapped to genes:	15,331,342
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/530_RNA_pA_1.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/530_RNA_pA_1.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	530_RNA_pA_2.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	530_RNA_pA_2.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			14,897,898
# Total reads:			14,897,898
# INFO:__main__:Spliced reads ignored:		569,255
# Spliced reads ignored:		569,255
# INFO:__main__:Total reads mapped to genes:	13,586,095
# Total reads mapped to genes:	13,586,095
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/530_RNA_pA_2.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/530_RNA_pA_2.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	638_RNA_pA_1.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	638_RNA_pA_1.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			16,339,340
# Total reads:			16,339,340
# INFO:__main__:Spliced reads ignored:		644,340
# Spliced reads ignored:		644,340
# INFO:__main__:Total reads mapped to genes:	14,987,053
# Total reads mapped to genes:	14,987,053
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/638_RNA_pA_1.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/638_RNA_pA_1.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	638_RNA_pA_2.ztr.Aligned.sortedByCoord.out.bam
# Sample name:	638_RNA_pA_2.ztr.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			12,322,354
# Total reads:			12,322,354
# INFO:__main__:Spliced reads ignored:		437,074
# Spliced reads ignored:		437,074
# INFO:__main__:Total reads mapped to genes:	11,464,007
# Total reads mapped to genes:	11,464,007
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/638_RNA_pA_2.ztr.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/638_RNA_pA_2.ztr.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	80_RNA_pA.Aligned.sortedByCoord.out.bam
# Sample name:	80_RNA_pA.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			3,619,460
# Total reads:			3,619,460
# INFO:__main__:Spliced reads ignored:		127,855
# Spliced reads ignored:		127,855
# INFO:__main__:Total reads mapped to genes:	3,364,049
# Total reads mapped to genes:	3,364,049
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/80_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/80_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	301_RNA_pA.Aligned.sortedByCoord.out.bam
# Sample name:	301_RNA_pA.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			7,019,817
# Total reads:			7,019,817
# INFO:__main__:Spliced reads ignored:		244,756
# Spliced reads ignored:		244,756
# INFO:__main__:Total reads mapped to genes:	6,464,775
# Total reads mapped to genes:	6,464,775
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/301_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/301_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	302_RNA_pA.Aligned.sortedByCoord.out.bam
# Sample name:	302_RNA_pA.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			15,257,000
# Total reads:			15,257,000
# INFO:__main__:Spliced reads ignored:		478,290
# Spliced reads ignored:		478,290
# INFO:__main__:Total reads mapped to genes:	14,024,513
# Total reads mapped to genes:	14,024,513
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/302_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/302_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	324_RNA_pA.Aligned.sortedByCoord.out.bam
# Sample name:	324_RNA_pA.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			5,720,621
# Total reads:			5,720,621
# INFO:__main__:Spliced reads ignored:		176,624
# Spliced reads ignored:		176,624
# INFO:__main__:Total reads mapped to genes:	5,255,239
# Total reads mapped to genes:	5,255,239
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/324_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	491_RNA_pA.Aligned.sortedByCoord.out.bam
# Sample name:	491_RNA_pA.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			20,375,053
# Total reads:			20,375,053
# INFO:__main__:Spliced reads ignored:		648,253
# Spliced reads ignored:		648,253
# INFO:__main__:Total reads mapped to genes:	18,665,318
# Total reads mapped to genes:	18,665,318
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/491_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/491_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Sample name:	510_RNA_pA.Aligned.sortedByCoord.out.bam
# Sample name:	510_RNA_pA.Aligned.sortedByCoord.out.bam
# INFO:__main__:-------------------------
# -------------------------
# INFO:__main__:Total reads:			17,730,562
# Total reads:			17,730,562
# INFO:__main__:Spliced reads ignored:		556,417
# Spliced reads ignored:		556,417
# INFO:__main__:Total reads mapped to genes:	16,375,919
# Total reads mapped to genes:	16,375,919
# INFO:__main__:Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/510_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# Output file:	/data/pablo/RNAdeg/results/RipRna/tagged_bams/510_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# INFO:__main__:
#
# INFO:__main__:
#
# INFO:__main__:Finished successfully!
# Finished successfully!

# %% [markdown]
# ### 5 - Compute raw and tpm-normalized gene count tables.

# %%
# Set GeneExpressionTable runtime parameters.
def gxt_command():
    
    #gxt = '/data/parastou/RNAdeg/pyRNAdeg/GeneExpressionTable.py' ## doesn't exist
    ## not sure which one to use:
    gxt = '/data/parastou/RNAdeg/pyRNAdeg/gene_expression_table.py'
    #gxt = '/data/parastou/RNAdeg/pyRNAdeg/gene_expression_table_extended.py' ## strand-specific

    annotation = '/data/parastou/RNAdeg/annotation/schizosaccharomyces_pombe.chr.extended.csv'
    
    command = 'python ' + gxt + ' -d ' + out_tagged + ' -g ' + annotation + ' -o ' + xp_data
    
    return command

# %%
# Run GeneExpressionTable
gxt = gxt_command()
# !$gxt
# Out:
# Call to GeneExpressionTable module....
#
# This module calculates gene expression in given alignment file(s).
# Input: folder containing .bam file(s)
# Output: raw and tpm gene counts data (.csv) files
# ----------------------------------------
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/1113_pA.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 29738993
# Spliced alignments : 0
# Non spliced : 29738993
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/301_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 3236804
# Spliced alignments : 0
# Non spliced : 3236804
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/302_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 4597762
# Spliced alignments : 0
# Non spliced : 4597762
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/491_S2RIP_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 3071513
# Spliced alignments : 0
# Non spliced : 3071513
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 21344379
# Spliced alignments : 0
# Non spliced : 21344379
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/302_S2RIP_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 3269901
# Spliced alignments : 0
# Non spliced : 3269901
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/491_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 2997211
# Spliced alignments : 0
# Non spliced : 2997211
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/63.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 21787274
# Spliced alignments : 0
# Non spliced : 21787274
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/301_S2RIP_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 2280485
# Spliced alignments : 0
# Non spliced : 2280485
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/301_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 6126317
# Spliced alignments : 0
# Non spliced : 6126317
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/65.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 20323060
# Spliced alignments : 0
# Non spliced : 20323060
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_pA.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 31125631
# Spliced alignments : 0
# Non spliced : 31125631
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/324_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 5834619
# Spliced alignments : 0
# Non spliced : 5834619
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/63_RIPS5P.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 9514580
# Spliced alignments : 0
# Non spliced : 9514580
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/1168_pA.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 3408617
# Spliced alignments : 0
# Non spliced : 3408617
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/63_S2Ph_RIP.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 6823978
# Spliced alignments : 0
# Non spliced : 6823978
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/324_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 498497
# Spliced alignments : 0
# Non spliced : 498497
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/324S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 287921
# Spliced alignments : 0
# Non spliced : 287921
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/491_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 6443227
# Spliced alignments : 0
# Non spliced : 6443227
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/63_S2PRIP.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 7866524
# Spliced alignments : 0
# Non spliced : 7866524
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/510_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 4976016
# Spliced alignments : 0
# Non spliced : 4976016
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/63_S2RIP_2.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 1867093
# Spliced alignments : 0
# Non spliced : 1867093
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/491S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 132433
# Spliced alignments : 0
# Non spliced : 132433
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/63_S5Ph_RIP.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 1829553
# Spliced alignments : 0
# Non spliced : 1829553
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/80_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 5194321
# Spliced alignments : 0
# Non spliced : 5194321
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/80S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 2003218
# Spliced alignments : 0
# Non spliced : 2003218
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/80S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 2088678
# Spliced alignments : 0
# Non spliced : 2088678
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/324_S2RIP_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 2908584
# Spliced alignments : 0
# Non spliced : 2908584
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/504S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 2666658
# Spliced alignments : 0
# Non spliced : 2666658
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/504S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 2467902
# Spliced alignments : 0
# Non spliced : 2467902
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/530S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 1553833
# Spliced alignments : 0
# Non spliced : 1553833
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/530S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 2124538
# Spliced alignments : 0
# Non spliced : 2124538
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/591_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 3620178
# Spliced alignments : 0
# Non spliced : 3620178
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/301_RNA_pA_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 15000993
# Spliced alignments : 0
# Non spliced : 15000993
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/591_S5RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 4793897
# Spliced alignments : 0
# Non spliced : 4793897
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/638S2RIP_1.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 1797023
# Spliced alignments : 0
# Non spliced : 1797023
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/638S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 1717818
# Spliced alignments : 0
# Non spliced : 1717818
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/504_RNA_pA_1.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 18161544
# Spliced alignments : 0
# Non spliced : 18161544
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/1113_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 5283626
# Spliced alignments : 0
# Non spliced : 5283626
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 2791797
# Spliced alignments : 0
# Non spliced : 2791797
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 2521778
# Spliced alignments : 0
# Non spliced : 2521778
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/1167_S5RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 1498893
# Spliced alignments : 0
# Non spliced : 1498893
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/1168_S2RIP_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 2488945
# Spliced alignments : 0
# Non spliced : 2488945
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/1168_S2RIP.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 1445836
# Spliced alignments : 0
# Non spliced : 1445836
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/301_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 18491678
# Spliced alignments : 0
# Non spliced : 18491678
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/324_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 18429178
# Spliced alignments : 0
# Non spliced : 18429178
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/324_RNA_pA_3.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 15081399
# Spliced alignments : 0
# Non spliced : 15081399
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/504_RNA_pA_2.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 15064485
# Spliced alignments : 0
# Non spliced : 15064485
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/1168_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 17639735
# Spliced alignments : 0
# Non spliced : 17639735
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/302_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 16010878
# Spliced alignments : 0
# Non spliced : 16010878
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/63_RNA_pA_4.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 15979307
# Spliced alignments : 0
# Non spliced : 15979307
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/510_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 23628436
# Spliced alignments : 0
# Non spliced : 23628436
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/80pARNA_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 15425726
# Spliced alignments : 0
# Non spliced : 15425726
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/283_RNA_pA_4.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 16896935
# Spliced alignments : 0
# Non spliced : 16896935
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/491_RNA_pA_2.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 25588457
# Spliced alignments : 0
# Non spliced : 25588457
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/530_RNA_pA_1.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 18847124
# Spliced alignments : 0
# Non spliced : 18847124
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/530_RNA_pA_2.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 16765174
# Spliced alignments : 0
# Non spliced : 16765174
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/638_RNA_pA_1.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 18424044
# Spliced alignments : 0
# Non spliced : 18424044
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/638_RNA_pA_2.ztr.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 14065835
# Spliced alignments : 0
# Non spliced : 14065835
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/80_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 4144030
# Spliced alignments : 0
# Non spliced : 4144030
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/301_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 8002623
# Spliced alignments : 0
# Non spliced : 8002623
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/302_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 17211463
# Spliced alignments : 0
# Non spliced : 17211463
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/324_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 6455132
# Spliced alignments : 0
# Non spliced : 6455132
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/491_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 22878678
# Spliced alignments : 0
# Non spliced : 22878678
# Input bam: /data/pablo/RNAdeg/results/RipRna/tagged_bams/510_RNA_pA.Aligned.sortedByCoord.out.tagged.bam
# Total number of alignments : 19789253
# Spliced alignments : 0
# Non spliced : 19789253
# Removed 49 rRNA genes.
# Calculated raw counts for 6943 genes.
# Calculated TMP for 6943 genes.
# Gene count matrix saved in: /data/pablo/RNAdeg/results/RipRna/xp_data/gene_count_table.csv
# TPM expression matrix saved in: /data/pablo/RNAdeg/results/RipRna/xp_data/tpm_table.csv
# Finished successfully!

# %% [markdown]
# ----------------
